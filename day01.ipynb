# %%
print("hello world")
# Out:
# hello world

# %%
# BUILD A CALCULATOR
#concepts : type casting , variable, data type,i/o functions
a = int(input("enter first number :  "))
b = int(input("enter second number :  "))
print("addition is : ",a+b)
print("substraction is :  ",a-b)
print("multiplication is :  ",a*b)
print("division is :  ",a/b)
# Out:
# enter first number :  10
# enter second number :  5
# addition is :  15
# substraction is :   5
# multiplication is :   50
# division is :   2.0

# %%
name = input("enter your name :  ")
age = int(input("enter your age: "))
dept = input("enter your department")
print(f"my name is {name}, age is {age},department is {dept} ")
# Out:
# enter your name :  ashim
# enter your age: 20
# enter your departmentece
# my name is ashim, age is 20,department is ece

# %%
#take two numbers and print their sum
a=float(input("the first number is  :  "))
b= float(input("second number is :  "))
print(a+b)
# Out:
# the first number is  :  60.66
# second number is :  7.90
# 68.56

# %%
#take city as input and print
city=input("enter the city name: ")
print(city)
# Out:
# enter the city name: kharda
# kharda

# %%
#create a variable for name , salary , and job role
name = input("enter your name :  ")
salary = float(input("your salary :  "))
job_role = input("your job role is : ")
print(f"mame is{name}, salary is {salary}, job role is {job_role}")
# Out:
# enter your name :  ashim
# your salary :  40000.00
# your job role is : data holder
# mame isashim, salary is 40000.0, job role is data holder

# %%
#popular data types  in python
#list vs tupple
role= ["AI ENGINEER","FREELANCER SOFTWARE DEVELOPER", " DESIGNER" , "TESTER"]
ages= (18,19,20,21,22,23)


#set vs dictionary

# %%
#if else statements and indentation
#let's find greatest number among three numbers
#logical operators : and , or, not
a=int(input("enter a:  "))
b= int(input("enter b"))
c = int(input("enter c "))
if a>b and a>c:
  print("a is the greatest")
elif b>a and b>c:
  print("b is the greatest")
else:
  print("c is the greatest")
# Out:
# enter a:  10
# enter b15
# enter c 25
# c is the greatest

# %%
#modules
import math
a= 25
print(math.sqrt(a))
# Out:
# 5.0

# %%
import datetime
a= datetime.datetime.now()
print(a)
# Out:
# 2026-03-16 07:22:11.978345
